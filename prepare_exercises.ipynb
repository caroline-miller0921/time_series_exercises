# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import prepare

# %%
# sheet_url = 'https://drive.google.com/file/d/1Qg9S7NkrHPBACdpNq3H_I-A_wCNiU6sZ/export?format=csv&gid='    

# # csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# df = pd.read_csv(sheet_url)
# df.head()

# %% [markdown]
# #### Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %%
url = 'https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv'

df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %%
df.Date.nunique()
# Out:
# 4383

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# 1. Convert date column to datetime format.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.Date.nunique()
# Out:
# 4383

# %% [markdown]
# 3. Set the index to be the datetime variable.

# %%
df = df.set_index('Date').sort_index()

# %%
df
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
df.Consumption.mean()
# Out:
# 1338.6758355897814

# %% [markdown]
# 2. Plot the distribution of each of your variables.

# %%
for col in df.columns:
    print(f'Univariate Visualization of {col}')
    plt.hist(df[col], color='violet', edgecolor='black')
    plt.axhline(df[col].mean())
    plt.show()
# Out:
# Univariate Visualization of Consumption
# Univariate Visualization of Wind
# Univariate Visualization of Solar
# Univariate Visualization of Wind+Solar

# %% [markdown]
# 4. Add a month and a year column to your dataframe.

# %%
df['month'] = df.index.month

# %%
df['year'] = df.index.year

# %%
df
# Out:
#             Consumption     Wind   Solar  Wind+Solar  month  year
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN      1  2006
# 2006-01-02   1380.52100      NaN     NaN         NaN      1  2006
# 2006-01-03   1442.53300      NaN     NaN         NaN      1  2006
# 2006-01-04   1457.21700      NaN     NaN         NaN      1  2006
# 2006-01-05   1477.13100      NaN     NaN         NaN      1  2006
# ...                 ...      ...     ...         ...    ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037     12  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586     12  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131     12  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714     12  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156     12  2017
#
# [4383 rows x 6 columns]

# %% [markdown]
# 5. Fill any missing values.

# %%
df = df.fillna(0)

# %% [markdown]
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
df = prepare.prepare_opsd_germany_daily()
df
# Out:
#             Consumption     Wind   Solar  Wind+Solar  month  year
# Date
# 2006-01-01   1069.18400    0.000   0.000       0.000      1  2006
# 2006-01-02   1380.52100    0.000   0.000       0.000      1  2006
# 2006-01-03   1442.53300    0.000   0.000       0.000      1  2006
# 2006-01-04   1457.21700    0.000   0.000       0.000      1  2006
# 2006-01-05   1477.13100    0.000   0.000       0.000      1  2006
# ...                 ...      ...     ...         ...    ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037     12  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586     12  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131     12  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714     12  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156     12  2017
#
# [4383 rows x 6 columns]

# %%
prepare.univariate_viz(df)
# Out:
# Univariate Visualization of Consumption
# Univariate Visualization of Wind
# Univariate Visualization of Solar
# Univariate Visualization of Wind+Solar
# Univariate Visualization of month
# Univariate Visualization of year

# %% [markdown]
# #### Using your store items data:

# %%
df = prepare.aqcuire_store_data()

# %%
df
# Out:
#         Unnamed: 0  item  sale_amount                      sale_date  sale_id  \
# 0                0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1                1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2                2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3                3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4                4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
# ...            ...   ...          ...                            ...      ...
# 912995      912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996
# 912996      912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997
# 912997      912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998
# 912998      912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999
# 912999      912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000
#
#         store           store_address   store_city  store_id store_state  \
# 0           1  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 1           1  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 2           1  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 3           1  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 4           1  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# ...       ...                     ...          ...       ...         ...
# 912995     10    8503 NW Military Hwy  San Antonio        10          TX
# 912996     10    8503 NW Military Hwy  San Antonio        10          TX
# 912997     10    8503 NW Military Hwy  San Antonio        10          TX
# 912998     10    8503 NW Military Hwy  San Antonio        10          TX
# 912999     10    8503 NW Military Hwy  San Antonio        10          TX
#
#         store_zipcode item_brand  item_id  \
# 0               78253   Riceland        1
# 1               78253   Riceland        1
# 2               78253   Riceland        1
# 3               78253   Riceland        1
# 4               78253   Riceland        1
# ...               ...        ...      ...
# 912995          78231     Choice       50
# 912996          78231     Choice       50
# 912997          78231     Choice       50
# 912998          78231     Choice       50
# 912999          78231     Choice       50
#
#                                                 item_name  item_price  \
# 0                          Riceland American Jazmine Rice        0.84
# 1                          Riceland American Jazmine Rice        0.84
# 2                          Riceland American Jazmine Rice        0.84
# 3                          Riceland American Jazmine Rice        0.84
# 4                          Riceland American Jazmine Rice        0.84
# ...                                                   ...         ...
# 912995  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912996  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912997  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912998  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912999  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#          item_upc12   item_upc14
# 0       35200264013  35200264013
# 1       35200264013  35200264013
# 2       35200264013  35200264013
# 3       35200264013  35200264013
# 4       35200264013  35200264013
# ...             ...          ...
# 912995  47445919221  47445919221
# 912996  47445919221  47445919221
# 912997  47445919221  47445919221
# 912998  47445919221  47445919221
# 912999  47445919221  47445919221
#
# [913000 rows x 17 columns]

# %% [markdown]
# 1. Convert date column to datetime format.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     913000 non-null  int64
#  1   item           913000 non-null  int64
#  2   sale_amount    913000 non-null  float64
#  3   sale_date      913000 non-null  object
#  4   sale_id        913000 non-null  int64
#  5   store          913000 non-null  int64
#  6   store_address  913000 non-null  object
#  7   store_city     913000 non-null  object
#  8   store_id       913000 non-null  int64
#  9   store_state    913000 non-null  object
#  10  store_zipcode  913000 non-null  int64
#  11  item_brand     913000 non-null  object
#  12  item_id        913000 non-null  int64
#  13  item_name      913000 non-null  object
#  14  item_price     913000 non-null  float64
#  15  item_upc12     913000 non-null  int64
#  16  item_upc14     913000 non-null  int64
# dtypes: float64(2), int64(9), object(6)
# memory usage: 118.4+ MB

# %%
df['sale_date'] = df['sale_date'].str.replace(' 00:00:00 GMT', '')

# %%
df['sale_date'] = pd.to_datetime(df.sale_date)

# %%
df.head()
# Out:
#    Unnamed: 0  item  sale_amount  sale_date  sale_id  store  \
# 0           0     1         13.0 2013-01-01        1      1
# 1           1     1         11.0 2013-01-02        2      1
# 2           2     1         14.0 2013-01-03        3      1
# 3           3     1         13.0 2013-01-04        4      1
# 4           4     1         10.0 2013-01-05        5      1
#
#             store_address   store_city  store_id store_state  store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
#
#   item_brand  item_id                       item_name  item_price  \
# 0   Riceland        1  Riceland American Jazmine Rice        0.84
# 1   Riceland        1  Riceland American Jazmine Rice        0.84
# 2   Riceland        1  Riceland American Jazmine Rice        0.84
# 3   Riceland        1  Riceland American Jazmine Rice        0.84
# 4   Riceland        1  Riceland American Jazmine Rice        0.84
#
#     item_upc12   item_upc14
# 0  35200264013  35200264013
# 1  35200264013  35200264013
# 2  35200264013  35200264013
# 3  35200264013  35200264013
# 4  35200264013  35200264013

# %% [markdown]
# 2. Plot the distribution of sale_amount and item_price.

# %%
plt.hist(df['sale_amount'], color='teal', edgecolor='black')
plt.axvline(df.sale_amount.mean(), color='red', linestyle='dashed')
plt.title('Distribution of Sales Amount')
plt.xlabel('Sales (USD)')
plt.ylabel('Count of Sales')
plt.show()

# %%
plt.hist(df['item_price'], color='turquoise', edgecolor='black')
plt.axvline(df.item_price.mean(), color='red', linestyle='dashed')
plt.title('Distribution of Item Prices')
plt.xlabel('Prices (USD)')
plt.ylabel('Count of Items')
plt.show()

# %% [markdown]
# 3. Set the index to be the datetime variable.

# %%
df = df.set_index('sale_date').sort_index()

# %% [markdown]
# 4. Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month'] = df.index.month
df['day_of_week'] = df.index.day_of_week

# %%
df.head()
# Out:
#             Unnamed: 0  item  sale_amount  sale_id  store  \
# sale_date
# 2013-01-01           0     1         13.0        1      1
# 2013-01-01      211816    12         26.0   211817      7
# 2013-01-01      832656    46         27.0   832657      7
# 2013-01-01      213642    12         54.0   213643      8
# 2013-01-01      215468    12         35.0   215469      9
#
#                      store_address   store_city  store_id store_state  \
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 2013-01-01  12018 Perrin Beitel Rd  San Antonio         7          TX
# 2013-01-01  12018 Perrin Beitel Rd  San Antonio         7          TX
# 2013-01-01     15000 San Pedro Ave  San Antonio         8          TX
# 2013-01-01      735 SW Military Dr  San Antonio         9          TX
#
#             store_zipcode  item_brand  item_id  \
# sale_date
# 2013-01-01          78253    Riceland        1
# 2013-01-01          78217     Mueller       12
# 2013-01-01          78217  Mama Marys       46
# 2013-01-01          78232     Mueller       12
# 2013-01-01          78221     Mueller       12
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#              item_upc12   item_upc14  month  day_of_week
# sale_date
# 2013-01-01  35200264013  35200264013      1            1
# 2013-01-01  74676640211  74676640211      1            1
# 2013-01-01  35457770664  35457770664      1            1
# 2013-01-01  74676640211  74676640211      1            1
# 2013-01-01  74676640211  74676640211      1            1

# %% [markdown]
# 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df.sale_amount * df.item_price

# %%
df.head()
# Out:
#             Unnamed: 0  item  sale_amount  sale_id  store  \
# sale_date
# 2013-01-01           0     1         13.0        1      1
# 2013-01-01      211816    12         26.0   211817      7
# 2013-01-01      832656    46         27.0   832657      7
# 2013-01-01      213642    12         54.0   213643      8
# 2013-01-01      215468    12         35.0   215469      9
#
#                      store_address   store_city  store_id store_state  \
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 2013-01-01  12018 Perrin Beitel Rd  San Antonio         7          TX
# 2013-01-01  12018 Perrin Beitel Rd  San Antonio         7          TX
# 2013-01-01     15000 San Pedro Ave  San Antonio         8          TX
# 2013-01-01      735 SW Military Dr  San Antonio         9          TX
#
#             store_zipcode  item_brand  item_id  \
# sale_date
# 2013-01-01          78253    Riceland        1
# 2013-01-01          78217     Mueller       12
# 2013-01-01          78217  Mama Marys       46
# 2013-01-01          78232     Mueller       12
# 2013-01-01          78221     Mueller       12
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#              item_upc12   item_upc14  month  day_of_week  sales_total
# sale_date
# 2013-01-01  35200264013  35200264013      1            1        10.92
# 2013-01-01  74676640211  74676640211      1            1       218.40
# 2013-01-01  35457770664  35457770664      1            1       125.55
# 2013-01-01  74676640211  74676640211      1            1       453.60
# 2013-01-01  74676640211  74676640211      1            1       294.00

# %% [markdown]
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
df = prepare.prepare_store_data()

# %%
prepare.sales_viz(df)
